# %%
import pandas as pd
import numpy as np
import scipy as sp
from sklearn.model_selection import train_test_split
from scipy.sparse import csr_matrix
from sklearn.feature_selection import SelectFromModel
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.feature_selection import mutual_info_classif
from sklearn.tree import DecisionTreeClassifier

# %%
df1 = pd.read_csv('YelpDataset_Reviews_Stars_20K.csv',header=None)

# %%
pd.read_csv?

# %%
def filterLen(docs, minlen=3):
    import re, string
    docs_raw4 = [re.sub('[\W_]+','', t) for t in docs.split() if len(t) >= minlen ]
    s = " "
    return s.join(docs_raw4)

# %%
import re
re.sub('[\W_]+', '', '123&test')
# Out:
# '123test'

# %%
#filtered min len keywords
df1[1] = df1[1].apply(filterLen)

# %%
df1[1][15000:]
# Out:
# 15000    Someone please change the cooking oil With the...
# 15001    Yummy Chinese Food the corner Queen and Wilson...
# 15002    was really craving some noodles with beef and ...
# 15003    This our Chinese restaurant weve been using fo...
# 15004    Took while build the courage write review abou...
# 15005    This place has been here for long remember ser...
# 15006    This place great their food great but theyre n...
# 15007    Close and great sushiService was excellent and...
# 15008    This INJUSTICE Ramen After coming back from To...
# 15009    Went here today just because other ramen place...
# 15010    The one with the glasses teaThe GoodFriendly s...
# 15011    Came here whim after yoga class Kennedy RdWe h...
# 15012    Kyu Shou Japanese Noodle place you just want s...
# 15013    Sandwich most definitely favorite breakfastlun...
# 15014    Sandwich understated little sandwich bar Frede...
# 15015    went there this afternoon based yelps reviewso...
# 15016    was super impressed with the quality their fis...
# 15017    Their seafood the freshest Ive ever had Toront...
# 15018    Currently this favorite place order take out f...
# 15019    This the place you can get the most freshness ...
# 15020    Delicious plentiful and authentic Japanese ben...
# 15021    Fresh fish Great prices This place amazing Lik...
# 15022    custom ordered some sushi pieces yesterday for...
# 15023    This what Charlotte has been missing Authentic...
# 15024    love this place When traveling from and back s...
# 15025    youre looking for some good home southern cook...
# 15026    This place has great southern food Its very de...
# 15027    rating 35 starsIts good thing that didnt read ...
# 15028    This place was just ticketed public health ins...
# 15029    Some the best coffee Ive ever hadMade order it...
#                                ...
# 19970    Very disappointed Ramen broth lacked flavor No...
# 19971    Great service really ave food City Life loved ...
# 19972    Boston Market used have really good side dishe...
# 19973    The food pretty good usually loves the burgers...
# 19974    feel bad that was short with the lady from EAT...
# 19975    1022015You would think that wife and would eat...
# 19976    originally posted this review error Johnny Ban...
# 19977    may burrito biased because first experience wa...
# 19978    Covered greasy and bloated isnt what was hopin...
# 19979    Citrus renovating become C2 Until they move in...
# 19980    So this was our second attempt dinning Forte B...
# 19981    dont eat much pizza but the stuff have had fro...
# 19982    There are times your life when you raise the w...
# 19983    Food great staff are friendly and helpful when...
# 19984    love Georgios pizza Five bucks for fresh and r...
# 19985    Disappointing the best summary our dining expe...
# 19986    Furio came highly recommended made reservation...
# 19987    Standard fare there pretty much summed what yo...
# 19988    went here last night with some friends from ou...
# 19989    Im not that big fan Hero Burger but considerin...
# 19990    Im actually not sure how well speaks the Duke ...
# 19991    This Takeout only Sushi place course designed ...
# 19992    really wanted give this place chance ordered f...
# 19993    trying review the Progressive Field location T...
# 19994    asked for burger come with sauce because cant ...
# 19995    This place closed during the winter and they f...
# 19996    Wish they could cook these order Ordered mediu...
# 19997    Great staff but the veggie burger not that goo...
# 19998    The best part about Dynomite Burgers that you ...
# 19999    Super long wait during lunch time Passable fla...
# Name: 1, dtype: object

# %%
X_train, X_test,y_train,y_test = df1[1][:15000],df1[1][15000:], df1[0][:15000], df1[0][15000:]

# %%
from nltk import word_tokenize          
from nltk.stem import WordNetLemmatizer 
class LemmaTokenizer(object):
    def __init__(self):
         self.wnl = WordNetLemmatizer()
    def __call__(self, doc):
         return [self.wnl.lemmatize(t) for t in word_tokenize(doc)]

# %%
def makeVectorizer(max_df,min_df,norm,stopwords,lemmatizer):
    from sklearn.feature_extraction.text import CountVectorizer
    from sklearn.feature_extraction.text import TfidfVectorizer
    vectorizer = TfidfVectorizer(lowercase = True,
                                stop_words = stopwords,
                                 max_df = max_df,
                                 min_df = min_df,
                                 norm = norm,
                                 tokenizer = lemmatizer)
    return vectorizer

# %%
lemmatizer = LemmaTokenizer()

# %%
vectorizer_idf = makeVectorizer(0.01,0.0005,'l2','english',lemmatizer)
vectorizer_idf_nolem=makeVectorizer(0.01,0.0005,'l2','english',None)

# %%
vectorizer_idf.fit(X_train)
vectorizer_idf_nolem.fit(X_train)
# Out:
# TfidfVectorizer(analyzer=u'word', binary=False, decode_error=u'strict',
#         dtype=<type 'numpy.int64'>, encoding=u'utf-8', input=u'content',
#         lowercase=True, max_df=0.01, max_features=None, min_df=0.0005,
#         ngram_range=(1, 1), norm='l2', preprocessor=None, smooth_idf=True,
#         stop_words='english', strip_accents=None, sublinear_tf=False,
#         token_pattern=u'(?u)\\b\\w\\w+\\b', tokenizer=None, use_idf=True,
#         vocabulary=None)

# %%
vectorizer_idf.get_feature_names()
# Out:
# [u'1',
#  u'100',
#  u'1000',
#  u'101',
#  u'1010',
#  u'1012',
#  u'1015',
#  u'1030',
#  u'1050',
#  u'1095',
#  u'1099',
#  u'10am',
#  u'10pm',
#  u'11',
#  u'110',
#  u'1100',
#  u'1130',
#  u'115',
#  u'1150',
#  u'1195',
#  u'1199',
#  u'11am',
#  u'11pm',
#  u'120',
#  u'1200',
#  u'125',
#  u'1295',
#  u'1299',
#  u'13',
#  u'130',
#  u'14',
#  u'140',
#  u'1499',
#  u'150',
#  u'1520',
#  u'1599',
#  u'16',
#  u'1699',
#  u'16oz',
#  u'17',
#  u'18',
#  u'1895',
#  u'19',
#  u'199',
#  u'1999',
#  u'1pm',
#  u'1st',
#  u'2',
#  u'200',
#  u'2000',
#  u'2008',
#  u'2009',
#  u'2010',
#  u'2011',
#  u'2012',
#  u'2013',
#  u'2014',
#  u'2015',
#  u'2025',
#  u'2030',
#  u'21',
#  u'21st',
#  u'22',
#  u'225',
#  u'23',
#  u'230',
#  u'24',
#  u'247',
#  u'25',
#  u'250',
#  u'26',
#  u'27',
#  u'275',
#  u'28',
#  u'299',
#  u'2am',
#  u'2nd',
#  u'2pm',
#  u'3',
#  u'30',
#  u'300',
#  u'3040',
#  u'31',
#  u'32',
#  u'34',
#  u'35',
#  u'350',
#  u'375',
#  u'399',
#  u'3am',
#  u'3pm',
#  u'3rd',
#  u'3star',
#  u'4',
#  u'40',
#  u'400',
#  u'425',
#  u'45',
#  u'450',
#  u'46',
#  u'495',
#  u'499',
#  u'4pm',
#  u'4th',
#  u'5',
#  u'50',
#  u'500',
#  u'510',
#  u'530',
#  u'55',
#  u'550',
#  u'56',
#  u'57',
#  u'575',
#  u'58',
#  u'595',
#  u'599',
#  u'5pm',
#  u'5star',
#  u'5th',
#  u'6',
#  u'60',
#  u'600',
#  u'630',
#  u'630pm',
#  u'65',
#  u'650',
#  u'67',
#  u'695',
#  u'699',
#  u'6pm',
#  u'6th',
#  u'7',
#  u'70',
#  u'700',
#  u'710',
#  u'730',
#  u'730pm',
#  u'75',
#  u'750',
#  u'78',
#  u'795',
#  u'799',
#  u'7pm',
#  u'7th',
#  u'8',
#  u'80',
#  u'800',
#  u'810',
#  u'830',
#  u'830pm',
#  u'850',
#  u'895',
#  u'899',
#  u'8am',
#  u'8oz',
#  u'8pm',
#  u'8th',
#  u'9',
#  u'90',
#  u'900',
#  u'910',
#  u'930',
#  u'930pm',
#  u'95',
#  u'950',
#  u'99',
#  u'990',
#  u'995',
#  u'999',
#  u'9pm',
#  u'abandoned',
#  u'ability',
#  u'aboutthe',
#  u'absolute',
#  u'absorbed',
#  u'absurd',
#  u'abundance',
#  u'abundant',
#  u'abysmal',
#  u'ac',
#  u'accent',
#  u'accept',
#  u'acceptable',
#  u'accepted',
#  u'accepting',
#  u'accepts',
#  u'access',
#  u'accessible',
#  u'accessory',
#  u'accident',
#  u'accidentally',
#  u'accommodate',
#  u'accommodated',
#  u'accommodating',
#  u'accomodating',
#  u'accompanied',
#  u'accompaniment',
#  u'accompany',
#  u'accompanying',
#  u'according',
#  u'accordingly',
#  u'account',
#  u'accurate',
#  u'accustomed',
#  u'acidic',
#  u'ackee',
#  u'acknowledge',
#  u'acknowledged',
#  u'acoustic',
#  u'acquired',
#  u'act',
#  u'acted',
#  u'acting',
#  u'action',
#  u'active',
#  u'activity',
#  u'actual',
#  u'ad',
#  u'adam',
#  u'addicted',
#  u'addicting',
#  u'addictive',
#  u'adding',
#  u'additional',
#  u'additionally',
#  u'address',
#  u'adequate',
#  u'adequately',
#  u'adjacent',
#  u'adjoining',
#  u'adjust',
#  u'adjustment',
#  u'admire',
#  u'admission',
#  u'admit',
#  u'admitted',
#  u'admittedly',
#  u'adorable',
#  u'adore',
#  u'adult',
#  u'advance',
#  u'advantage',
#  u'adventure',
#  u'adventurous',
#  u'advertise',
#  u'advertised',
#  u'advertisement',
#  u'advertises',
#  u'advertising',
#  u'advice',
#  u'advise',
#  u'advised',
#  u'affair',
#  u'affect',
#  u'afford',
#  u'affordable',
#  u'aforementioned',
#  u'afraid',
#  u'african',
#  u'aftertaste',
#  u'afterthought',
#  u'afterward',
#  u'afterwork',
#  u'againi',
#  u'againthe',
#  u'agave',
#  u'age',
#  u'aged',
#  u'agedashi',
#  u'aggressive',
#  u'agreed',
#  u'ah',
#  u'ahi',
#  u'aid',
#  u'aim',
#  u'aimlessly',
#  u'aint',
#  u'aioli',
#  u'air',
#  u'airport',
#  u'airy',
#  u'aisle',
#  u'ajs',
#  u'aka',
#  u'al',
#  u'ala',
#  u'albacore',
#  u'albeit',
#  u'alcohol',
#  u'alcoholic',
#  u'ale',
#  u'alert',
#  u'alfredo',
#  u'alike',
#  u'alittle',
#  u'alive',
#  u'alla',
#  u'allday',
#  u'allergic',
#  u'allergy',
#  u'alley',
#  u'alli',
#  u'allow',
#  u'allowed',
#  u'allowing',
#  u'allows',
#  u'allthe',
#  u'allyoucaneat',
#  u'almond',
#  u'aloha',
#  u'alongside',
#  u'aloo',
#  u'alot',
#  u'alright',
#  u'alternative',
#  u'altogether',
#  u'amateur',
#  u'amazed',
#  u'amazingi',
#  u'amazingly',
#  u'amazingthe',
#  u'ambience',
#  u'america',
#  u'americanized',
#  u'americano',
#  u'amigo',
#  u'ample',
#  u'amuse',
#  u'amusing',
#  u'anchovy',
#  u'andor',
#  u'andrew',
#  u'angel',
#  u'angeles',
#  u'angelina',
#  u'angry',
#  u'angus',
#  u'animal',
#  u'annex',
#  u'anniversary',
#  u'announced',
#  u'annoyance',
#  u'annoyed',
#  u'annoying',
#  u'annual',
#  u'answer',
#  u'answered',
#  u'answering',
#  u'anticipated',
#  u'anticipation',
#  u'antipasti',
#  u'antipasto',
#  u'antique',
#  u'anxious',
#  u'anybody',
#  u'anymore',
#  u'anyones',
#  u'anytime',
#  u'anyways',
#  u'aok',
#  u'apache',
#  u'apart',
#  u'apartment',
#  u'apologetic',
#  u'apologize',
#  u'apologized',
#  u'apologizing',
#  u'apology',
#  u'app',
#  u'appalled',
#  u'appalling',
#  u'apparent',
#  u'appeal',
#  u'appealing',
#  u'appear',
#  u'appearance',
#  u'appeared',
#  u'appears',
#  u'appetite',
#  u'appetizing',
#  u'applebees',
#  u'applied',
#  u'apply',
#  u'appointment',
#  u'appreciate',
#  u'appreciated',
#  u'appreciation',
#  u'approach',
#  u'approached',
#  u'approaching',
#  u'appropriate',
#  u'appropriately',
#  u'approval',
#  u'approx',
#  u'approximately',
#  u'apps',
#  u'apricot',
#  u'april',
#  u'aquarium',
#  u'arbys',
#  u'arcade',
#  u'areai',
#  u'areathe',
#  u'argentina',
#  u'argentinian',
#  u'arguably',
#  u'argue',
#  u'argued',
#  u'arguing',
#  u'argument',
#  u'arizona',
#  u'arm',
#  u'aroma',
#  u'aromatic',
#  u'arpa',
#  u'arranged',
#  u'arrangement',
#  u'array',
#  u'arrival',
#  u'arrive',
#  u'arrives',
#  u'arriving',
#  u'arrogant',
#  u'art',
#  u'artery',
#  u'artichoke',
#  u'article',
#  u'artificial',
#  u'artisan',
#  u'artist',
#  u'artistic',
#  u'artwork',
#  u'arugula',
#  u'asada',
#  u'asap',
#  u'ashamed',
#  u'asia',
#  u'asiago',
#  u'aside',
#  u'asks',
#  u'asparagus',
#  u'aspect',
#  u'assembled',
#  u'assist',
#  u'assistant',
#  u'associated',
#  u'assorted',
#  u'assortment',
#  u'assume',
#  u'assumed',
#  u'assuming',
#  u'assure',
#  u'assured',
#  u'asu',
#  u'atlantic',
#  u'atleast',
#  u'atm',
#  u'atmospherethe',
#  u'atop',
#  u'atrocious',
#  u'attached',
#  u'attack',
#  u'attempt',
#  u'attempted',
#  u'attempting',
#  u'attend',
#  u'attendant',
#  u'attended',
#  u'attending',
#  u'attentivethe',
#  u'attitude',
#  u'attract',
#  u'attraction',
#  u'attractive',
#  u'aubergine',
#  u'audience',
#  u'august',
#  u'aunt',
#  u'aurora',
#  u'authentically',
#  u'authenticity',
#  u'automatic',
#  u'automatically',
#  u'avacado',
#  u'availability',
#  u'ave',
#  u'avenue',
#  u'avid',
#  u'avoided',
#  u'avoiding',
#  u'aw',
#  u'award',
#  u'aware',
#  u'awesomeness',
#  u'awesomethe',
#  u'awhile',
#  u'awkward',
#  u'awkwardly',
#  u'ayce',
#  u'az',
#  u'b',
#  u'baba',
#  u'baby',
#  u'backed',
#  u'background',
#  u'backi',
#  u'backthe',
#  u'backyard',
#  u'badi',
#  u'badly',
#  u'badthe',
#  u'baffled',
#  u'bagel',
#  u'bagged',
#  u'baguette',
#  u'baja',
#  u'bake',
#  u'baker',
#  u'bakery',
#  u'baking',
#  u'baklava',
#  u'balance',
#  u'balanced',
#  u'balcony',
#  u'ball',
#  u'ballantyne',
#  u'balloon',
#  u'balsamic',
#  u'bam',
#  u'bamboo',
#  u'ban',
#  u'banana',
#  u'band',
#  u'banditos',
#  u'bang',
#  u'bangkok',
#  u'banh',
#  u'bank',
#  u'banner',
#  u'banquet',
#  u'banter',
#  u'bao',
#  u'barbecue',
#  u'barbeque',
#  u'barcelona',
#  u'bare',
#  u'bargain',
#  u'barista',
#  u'barley',
#  u'barn',
#  u'barrel',
#  u'barrier',
#  u'base',
#  u'basement',
#  u'basil',
#  u'basis',
#  u'basket',
#  u'basketball',
#  u'basmati',
#  u'bass',
#  u'bastard',
#  u'bat',
#  u'batch',
#  u'batter',
#  u'battered',
#  u'bay',
#  u'bc',
#  u'beach',
#  u'bear',
#  u'bearing',
#  u'beast',
#  u'beat',
#  u'beaten',
#  u'beautifully',
#  u'beauty',
#  u'becuase',
#  u'bed',
#  u'bee',
#  u'beefy',
#  u'beet',
#  u'beg',
#  u'began',
#  u'begging',
#  u'begin',
#  u'beginning',
#  u'behavior',
#  u'behold',
#  u'belgian',
#  u'belief',
#  u'bell',
#  u'bellagio',
#  u'belle',
#  u'belly',
#  u'belong',
#  u'beloved',
#  u'belt',
#  u'ben',
#  u'bench',
#  u'benedict',
#  u'benefit',
#  u'benefited',
#  u'benkovitz',
#  u'benny',
#  u'bento',
#  u'berry',
#  u'bestthe',
#  u'bet',
#  u'betteri',
#  u'betterthe',
#  u'beverage',
#  u'beware',
#  u'bf',
#  u'bfs',
#  u'bias',
#  u'biased',
#  u'bibimbap',
#  u'bigger',
#  u'biggest',
#  u'biggie',
#  u'bike',
#  u'billy',
#  u'bin',
#  u'biodegradable',
#  u'bird',
#  u'biriyani',
#  u'biryani',
#  u'biscotti',
#  u'biscuit',
#  u'bison',
#  u'bisque',
#  u'bistro',
#  u'bitch',
#  u'biting',
#  u'bitter',
#  u'bivy',
#  u'biz',
#  u'bizarre',
#  u'bk',
#  u'blackberry',
#  u'blackened',
#  u'blah',
#  u'blame',
#  u'blamed',
#  u'blanc',
#  u'blandness',
#  u'blank',
#  u'blanket',
#  u'blaring',
#  u'blast',
#  u'blasting',
#  u'bleh',
#  u'blend',
#  u'blended',
#  u'blessing',
#  u'bleu',
#  u'blew',
#  u'blind',
#  u'blizzard',
#  u'bloated',
#  u'block',
#  u'blog',
#  u'blonde',
#  u'blood',
#  u'bloody',
#  u'bloomfield',
#  u'bloor',
#  u'blossom',
#  u'blow',
#  u'blowing',
#  u'blown',
#  u'blt',
#  u'blueberry',
#  u'blvd',
#  u'boar',
#  u'board',
#  u'boast',
#  u'boat',
#  u'bob',
#  u'boba',
#  u'bobby',
#  u'body',
#  u'boil',
#  u'boiled',
#  u'boiling',
#  u'bok',
#  u'bold',
#  u'bolognese',
#  u'bomb',
#  u'bombay',
#  u'bon',
#  u'bone',
#  u'bonein',
#  u'boneless',
#  u'bonus',
#  u'boo',
#  u'booked',
#  u'booking',
#  u'boom',
#  u'booming',
#  u'boot',
#  u'booze',
#  u'border',
#  u'bordering',
#  u'borderline',
#  u'bored',
#  u'boring',
#  u'born',
#  u'bos',
#  u'boston',
#  u'bother',
#  u'bothered',
#  u'bothering',
#  u'bottled',
#  u'bottomless',
#  u'bouche',
#  u'bought',
#  u'bouncer',
#  u'bound',
#  u'bourbon',
#  u'bourguignon',
#  u'bout',
#  u'boutique',
#  u'bowling',
#  u'boxed',
#  u'brad',
#  u'brag',
#  u'brain',
#  u'braised',
#  u'brampton',
#  u'branch',
#  u'brand',
#  u'brandy',
#  u'brasserie',
#  u'brat',
#  u'brau',
#  u'brave',
#  u'bravo',
#  u'brazilian',
#  u'breadcrumb',
#  u'breaded',
#  u'breading',
#  u'breadstick',
#  u'break',
#  u'breakfastbrunch',
#  u'breaking',
#  u'breast',
#  u'breath',
#  u'breathe',
#  u'breeze',
#  u'brew',
#  u'brewed',
#  u'brewery',
#  u'brewstone',
#  u'brick',
#  u'bridge',
#  u'brie',
#  u'brief',
#  u'briefly',
#  u'brighter',
#  u'brightly',
#  u'brilliant',
#  u'brim',
#  u'bringing',
#  u'brings',
#  u'brioche',
#  u'brisket',
#  u'british',
#  u'brle',
#  u'broad',
#  u'broccoli',
#  u'broccolini',
#  u'broiled',
#  u'broke',
#  u'broken',
#  u'brooklyn',
#  u'brossard',
#  u'brother',
#  u'broughton',
#  u'browned',
#  u'brownie',
#  u'browsing',
#  u'bruce',
#  u'brulee',
#  u'brunswick',
#  u'bruntsfield',
#  u'bruschetta',
#  u'brush',
#  u'brutal',
#  u'btw',
#  u'bubble',
#  u'bubbly',
#  u'bucket',
#  u'bud',
#  u'buddy',
#  u'budget',
#  u'bueno',
#  u'buffalo',
#  u'bug',
#  u'build',
#  u'built',
#  u'bulgarian',
#  u'bulgogi',
#  u'bulk',
#  u'bull',
#  u'bum',
#  u'bummed',
#  u'bummer',
#  u'bump',
#  u'bumped',
#  u'bumping',
#  u'bunch',
#  u'bundle',
#  u'burgerthe',
#  u'burgh',
#  u'burgundy',
#  u'burn',
#  u'burned',
#  u'burning',
#  u'burnt',
#  u'burro',
#  u'bursting',
#  u'bus',
#  u'busier',
#  u'businessi',
#  u'bustle',
#  u'bustling',
#  u'butcher',
#  u'butt',
#  u'buttered',
#  u'butternut',
#  u'buttery',
#  u'button',
#  u'buying',
#  u'buzz',
#  u'buzzing',
#  u'bye',
#  u'byo',
#  u'byob',
#  u'c',
#  u'ca',
#  u'cab',
#  u'cabbage',
#  u'cactus',
#  u'caesar',
#  u'caf',
#  u'cafeteria',
#  u'caffeine',
#  u'cajun',
#  u'calamari',
#  u'cali',
#  u'caliber',
#  u'california',
#  u'californian',
#  u'calling',
#  u'calm',
#  u'calorie',
#  u'calzone',
#  u'calzones',
#  u'camelback',
#  u'camera',
#  u'camp',
#  u'camper',
#  u'campus',
#  u'cana',
#  u'canada',
#  u'canadian',
#  u'canal',
#  u'cancel',
#  u'canceled',
#  u'cancelled',
#  u'candied',
#  u'candle',
#  u'candy',
#  u'cane',
#  u'canned',
#  u'cannelloni',
#  u'cannoli',
#  u'cantina',
#  u'cantine',
#  u'cantonese',
#  u'cap',
#  u'capable',
#  u'capacity',
#  u'caper',
#  u'capital',
#  u'cappuccino',
#  u'caprese',
#  u'captain',
#  u'caramel',
#  u'caramelized',
#  u'carb',
#  u'carbonara',
#  u'carbs',
#  u'cardboard',
#  u'cardos',
#  u'cared',
#  u'career',
#  u'careful',
#  u'carefully',
#  u'caribbean',
#  u'caring',
#  u'carls',
#  u'carmelized',
#  u'carne',
#  u'carnitas',
#  u'carnivore',
#  u'carolina',
#  u'carpaccio',
#  u'carpet',
#  u'carried',
#  u'carrot',
#  u'carry',
#  u'carrying',
#  u'carryout',
#  u'carson',
#  u'cart',
#  u'carte',
#  u'carton',
#  u'carved',
#  u'carving',
#  u'casa',
#  u'cashew',
#  u'cashier',
#  u'casino',
#  u'casserole',
#  u'cassoulet',
#  u'castle',
#  u'casually',
#  u'cat',
#  u'catch',
#  u'catching',
#  u'category',
#  u'cater',
#  u'catered',
#  u'catering',
#  u'caters',
#  u'catfish',
#  u'catherine',
#  u'caught',
#  u'cauliflower',
#  u'cause',
#  u'caused',
#  u'causing',
#  u'caution',
#  u'caveat',
#  u'caviar',
#  u'ceasar',
#  u'ceiling',
#  u'celebrate',
#  u'celebrated',
#  u'celebrating',
#  u'celebration',
#  u'celebrity',
#  u'celery',
#  u'cell',
#  u'cellar',
#  u'cent',
#  u'center',
#  u'central',
#  u'centre',
#  u'century',
#  u'cereal',
#  u'certain',
#  u'certificate',
#  u'cesar',
#  u'ceviche',
#  u'cha',
#  u'chai',
#  u'chalet',
#  u'chalk',
#  u'chalkboard',
#  u'challenge',
#  u'challenging',
#  u'champ',
#  u'champagne',
#  u'champaign',
#  u'chandelier',
#  u'chandler',
#  u'changing',
#  u'channel',
#  u'chaos',
#  u'chaotic',
#  u'char',
#  u'character',
#  u'charcoal',
#  u'charcuterie',
#  u'charging',
#  u'charity',
#  u'charlotte',
#  u'charm',
#  u'charming',
#  u'charred',
#  u'chase',
#  u'chat',
#  u'chatted',
#  u'chatting',
#  u'chatty',
#  u'cheapest',
#  u'cheat',
#  ...]

# %%
X_test_idf_l2_dtm = vectorizer_idf.transform(X_test)
X_train_idf_l2_dtm =vectorizer_idf.transform(X_train)

# %%
X_test_idf_l2_dtm_nolem = vectorizer_idf_nolem.transform(X_test)
X_train_idf_l2_dtm_nolem =vectorizer_idf_nolem.transform(X_train)

# %%
clfDT = DecisionTreeClassifier(max_depth=2000, class_weight='balanced',random_state=1)

# %%
clfDT.fit(X_train_idf_l2_dtm,y_train)
# Out:
# DecisionTreeClassifier(class_weight='balanced', criterion='gini',
#             max_depth=2500, max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=1, splitter='best')

# %%
DTres = clfDT.predict(X_test_idf_l2_dtm)

# %%
DTres
# Out:
# array([2, 1, 4, ..., 3, 2, 2])

# %%
clfDT.score(X_test_idf_l2_dtm,y_test)
# Out:
# 0.30719999999999997

# %%
def accuracy(res, y_test):
    sum = 0
    for i, j in enumerate(res):
        if j != y_test[i]:
            sum +=j-y_test[i]
    return float(sum)/float(len(res))

# %%
accuracy(DTres,list(y_test))
# Out:
# 0.7028

# %%
def testdepth(max_depth):
    score = []
    scores_nolem=[]
    for depth in max_depth:
        clfDT = DecisionTreeClassifier(max_depth=depth, class_weight='balanced',random_state=1)
        clfDT.fit(X_train_idf_l2_dtm,y_train)
        score.append(clfDT.score(X_test_idf_l2_dtm,y_test))
        clfDT.fit(X_train_idf_l2_dtm_nolem,y_train)
        scores_nolem.append(clfDT.score(X_test_idf_l2_dtm_nolem,y_test))
    return score, scores_nolem

# %%
deltas =np.array(y_test) - DTres

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
n,bin,patches=plt.hist(deltas,10)
plt.show()

# %%
max_depthlist = np.linspace(10,1001,dtype=int)

# %%
scores, scores_nolem = testdepth(max_depthlist)

# %%
plt.plot(max_depthlist,scores,'r--',max_depthlist,scores_nolem)
# Out:
# [<matplotlib.lines.Line2D at 0x11d2f2310>,
#  <matplotlib.lines.Line2D at 0x11d2f24d0>]

# %%
hist,bins = np.histogram(deltas)
center = (bins[:-1] + bins[1:]) / 2
